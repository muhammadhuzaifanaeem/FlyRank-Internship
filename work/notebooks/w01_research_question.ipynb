# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadhuzaifanaeem/FlyRank-Internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# I'm choosing Lane 2: Refresh / Content Opportunity Scoring. This lane asks which pages should be reviewed first for a refresh, expansion, or pruning decision. I picked it because the starter pipeline already runs this exact workflow end-to-end — a simple rule-based score compared against a trained model — which gives me a clear, provable story: does the model actually beat a simple guess, and by how much?

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This work supports one decision: out of thousands of pages, which ones should a content/SEO reviewer look at first, given limited time?
# The action is that a real person opens the top of the ranked list and decides whether to refresh, expand, or leave a page alone.
# The cost of a wrong recommendation is wasted reviewer time — someone spends an hour reworking a page that wasn't actually a problem, while a page that's genuinely losing traffic gets ignored for longer.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
df = pd.read_csv('FlyRank-Internship/data/raw/content_refresh_anonymized.csv')
print('Data Inspection :-\n')
print('Total Pages: ',len(df))
print('Total Rows: ', df.shape[0])
print('Total Columns: ', df.shape[1])

print('\nNumbers to Find:- \n')
print('Total pages marked as going down: ',(df['trend_direction'] =='down').sum())
print('Going down pages that still have trafic(from past 90 days and impressions>=500): ',((df['trend_direction'] =='down') & (df['impressions_90d']>=500)).sum())
# Out:
# Data Inspection :-
#
# Total Pages:  30000
# Total Rows:  30000
# Total Columns:  44
#
# Numbers to Find:-
#
# Total pages marked as going down:  16262
# Going down pages that still have trafic(from past 90 days and impressions>=500):  9961

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This work can say: which pages show patterns associated with decline or being overdue for review, based on observed data — a directional, decision-support signal.
# This work cannot say: that refreshing a page will cause its traffic to recover (that would require a controlled experiment), or that it reveals anything about Google's actual ranking algorithm.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
